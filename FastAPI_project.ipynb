# %% [markdown]
# # **Домашнее задание: API-сервис сокращения ссылок.**

# %% [markdown]
# ## **📌 Контекст задачи**:
#
# Вам предстоит разработать сервис, который позволяет пользователям сокращать длинные ссылки, получать их аналитику и управлять ими. Основная идея — пользователь вводит длинный URL, а ваш сервис генерирует для него короткую ссылку, которую можно использовать для быстрого доступа.
#
# **Как это работает:**
#
# - Пользователь отправляет запрос (`POST /links/shorten`) с длинной ссылкой.
#
# - Сервис генерирует уникальный короткий код и возвращает его пользователю.
#
# - При открытии короткой ссылки (`GET-запрос к /{short_code}`) сервис ищет в базе данных соответствующий оригинальный URL и перенаправляет пользователя (Redirect).
#
# **Примеры аналогичных сервисов:**
# - [tinyURL](https://tinyurl.com)
# - [bitly](https://bitly.com/)

# %%
# !pip3 install -r requirements-test.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pytest==8.0.2
#   Downloading pytest-8.0.2-py3-none-any.whl (333 kB)
#      |████████████████████████████████| 333 kB 5.0 MB/s eta 0:00:01
# Collecting pytest-asyncio==0.23.5
#   Downloading pytest_asyncio-0.23.5-py3-none-any.whl (17 kB)
# Collecting pytest-cov==4.1.0
#   Downloading pytest_cov-4.1.0-py3-none-any.whl (21 kB)
# Collecting pytest-mock==3.12.0
#   Downloading pytest_mock-3.12.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: httpx==0.27.0 in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from -r requirements-test.txt (line 5)) (0.27.0)
# Collecting locust==2.24.0
#   Downloading locust-2.24.0-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 2.9 MB/s eta 0:00:01
# Collecting coverage==7.4.3
#   Downloading coverage-7.4.3-cp39-cp39-macosx_11_0_arm64.whl (207 kB)
#      |████████████████████████████████| 207 kB 4.5 MB/s eta 0:00:01
# Requirement already satisfied: iniconfig in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from pytest==8.0.2->-r requirements-test.txt (line 1)) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=1.3.0 in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from pytest==8.0.2->-r requirements-test.txt (line 1)) (1.5.0)
# Requirement already satisfied: packaging in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from pytest==8.0.2->-r requirements-test.txt (line 1)) (23.2)
# Requirement already satisfied: tomli>=1.0.0 in /Library/Python/3.9/site-packages (from pytest==8.0.2->-r requirements-test.txt (line 1)) (2.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from pytest==8.0.2->-r requirements-test.txt (line 1)) (1.2.0)
# Collecting coverage[toml]>=5.2.1
#   Downloading coverage-7.8.0-cp39-cp39-macosx_11_0_arm64.whl (211 kB)
#      |████████████████████████████████| 211 kB 6.2 MB/s eta 0:00:01
# Requirement already satisfied: sniffio in /Library/Python/3.9/site-packages (from httpx==0.27.0->-r requirements-test.txt (line 5)) (1.3.0)
# Requirement already satisfied: httpcore==1.* in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from httpx==0.27.0->-r requirements-test.txt (line 5)) (1.0.5)
# Requirement already satisfied: idna in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from httpx==0.27.0->-r requirements-test.txt (line 5)) (3.6)
# Requirement already satisfied: anyio in /Library/Python/3.9/site-packages (from httpx==0.27.0->-r requirements-test.txt (line 5)) (4.2.0)
# Requirement already satisfied: certifi in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from httpx==0.27.0->-r requirements-test.txt (line 5)) (2023.11.17)
# Requirement already satisfied: Werkzeug>=2.0.0 in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from locust==2.24.0->-r requirements-test.txt (line 6)) (3.0.1)
# Collecting ConfigArgParse>=1.5.5
#   Downloading ConfigArgParse-1.7-py3-none-any.whl (25 kB)
# Requirement already satisfied: requests>=2.26.0 in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from locust==2.24.0->-r requirements-test.txt (line 6)) (2.31.0)
# Requirement already satisfied: pyzmq>=25.0.0 in /Library/Python/3.9/site-packages (from locust==2.24.0->-r requirements-test.txt (line 6)) (25.1.2)
# Collecting geventhttpclient>=2.0.11
#   Downloading geventhttpclient-2.3.3-cp39-cp39-macosx_11_0_arm64.whl (51 kB)
#      |████████████████████████████████| 51 kB 2.9 MB/s  eta 0:00:01
# Collecting Flask-Login>=0.6.3
#   Downloading Flask_Login-0.6.3-py3-none-any.whl (17 kB)
# Collecting roundrobin>=0.0.2
#   Downloading roundrobin-0.0.4.tar.gz (3.4 kB)
# Requirement already satisfied: psutil>=5.9.1 in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from locust==2.24.0->-r requirements-test.txt (line 6)) (5.9.6)
# Collecting Flask-Cors>=3.0.10
#   Downloading flask_cors-5.0.1-py3-none-any.whl (11 kB)
# Requirement already satisfied: flask>=2.0.0 in /Library/Python/3.9/site-packages (from locust==2.24.0->-r requirements-test.txt (line 6)) (3.0.2)
# Collecting gevent>=22.10.2
#   Downloading gevent-24.11.1.tar.gz (6.0 MB)
#      |████████████████████████████████| 6.0 MB 7.8 MB/s eta 0:00:01
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/2w/1s7n38315rx8pkdpz8t33nj00000gn/T/pip-build-env-t4p_kree/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/2w/1s7n38315rx8pkdpz8t33nj00000gn/T/pip-build-env-t4p_kree/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/2w/1s7n38315rx8pkdpz8t33nj00000gn/T/pip-build-env-t4p_kree/normal'
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/2w/1s7n38315rx8pkdpz8t33nj00000gn/T/pip-build-env-t4p_kree/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/2w/1s7n38315rx8pkdpz8t33nj00000gn/T/pip-build-env-t4p_kree/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/2w/1s7n38315rx8pkdpz8t33nj00000gn/T/pip-build-env-t4p_kree/overlay'
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: msgpack>=1.0.0 in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from locust==2.24.0->-r requirements-test.txt (line 6)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx==0.27.0->-r requirements-test.txt (line 5)) (0.14.0)
# Collecting coverage[toml]>=5.2.1
#   Downloading coverage-7.7.1-cp39-cp39-macosx_11_0_arm64.whl (211 kB)
#      |████████████████████████████████| 211 kB 9.6 MB/s eta 0:00:01
#   Downloading coverage-7.7.0-cp39-cp39-macosx_11_0_arm64.whl (211 kB)
#      |████████████████████████████████| 211 kB 17.9 MB/s eta 0:00:01
#   Downloading coverage-7.6.12-cp39-cp39-macosx_11_0_arm64.whl (208 kB)
#      |████████████████████████████████| 208 kB 15.3 MB/s eta 0:00:01
#   Downloading coverage-7.6.11-cp39-cp39-macosx_11_0_arm64.whl (208 kB)
#      |████████████████████████████████| 208 kB 22.3 MB/s eta 0:00:01
#   Downloading coverage-7.6.10-cp39-cp39-macosx_11_0_arm64.whl (208 kB)
#      |████████████████████████████████| 208 kB 15.1 MB/s eta 0:00:01
#   Downloading coverage-7.6.9-cp39-cp39-macosx_11_0_arm64.whl (207 kB)
#      |████████████████████████████████| 207 kB 9.0 MB/s eta 0:00:01
#   Downloading coverage-7.6.8-cp39-cp39-macosx_11_0_arm64.whl (207 kB)
#      |████████████████████████████████| 207 kB 19.1 MB/s eta 0:00:01
#   Downloading coverage-7.6.7-cp39-cp39-macosx_11_0_arm64.whl (207 kB)
#      |████████████████████████████████| 207 kB 3.0 MB/s eta 0:00:01
#   Downloading coverage-7.6.6-cp39-cp39-macosx_11_0_arm64.whl (207 kB)
#      |████████████████████████████████| 207 kB 3.3 MB/s eta 0:00:01
#   Downloading coverage-7.6.5-cp39-cp39-macosx_11_0_arm64.whl (207 kB)
#      |████████████████████████████████| 207 kB 5.4 MB/s eta 0:00:01
#   Downloading coverage-7.6.4-cp39-cp39-macosx_11_0_arm64.whl (207 kB)
#      |████████████████████████████████| 207 kB 3.7 MB/s eta 0:00:01
#   Downloading coverage-7.6.3-cp39-cp39-macosx_11_0_arm64.whl (207 kB)
#      |████████████████████████████████| 207 kB 3.1 MB/s eta 0:00:01
#   Downloading coverage-7.6.2-cp39-cp39-macosx_11_0_arm64.whl (206 kB)
#      |████████████████████████████████| 206 kB 3.4 MB/s eta 0:00:01
#   Downloading coverage-7.6.1-cp39-cp39-macosx_11_0_arm64.whl (207 kB)
#      |████████████████████████████████| 207 kB 3.4 MB/s eta 0:00:01
#   Downloading coverage-7.6.0-cp39-cp39-macosx_11_0_arm64.whl (206 kB)
#      |████████████████████████████████| 206 kB 3.3 MB/s eta 0:00:01
#   Downloading coverage-7.5.4-cp39-cp39-macosx_11_0_arm64.whl (205 kB)
#      |████████████████████████████████| 205 kB 2.6 MB/s eta 0:00:01
#   Downloading coverage-7.5.3-cp39-cp39-macosx_11_0_arm64.whl (204 kB)
#      |████████████████████████████████| 204 kB 2.9 MB/s eta 0:00:01
#   Downloading coverage-7.5.2-cp39-cp39-macosx_11_0_arm64.whl (204 kB)
#      |████████████████████████████████| 204 kB 3.6 MB/s eta 0:00:01
#   Downloading coverage-7.5.1-cp39-cp39-macosx_11_0_arm64.whl (204 kB)
#      |████████████████████████████████| 204 kB 3.6 MB/s eta 0:00:01
#   Downloading coverage-7.5.0-cp39-cp39-macosx_11_0_arm64.whl (210 kB)
#      |████████████████████████████████| 210 kB 3.5 MB/s eta 0:00:01
#   Downloading coverage-7.4.4-cp39-cp39-macosx_11_0_arm64.whl (206 kB)
#      |████████████████████████████████| 206 kB 3.0 MB/s eta 0:00:01
# Requirement already satisfied: click>=8.1.3 in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from flask>=2.0.0->locust==2.24.0->-r requirements-test.txt (line 6)) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from flask>=2.0.0->locust==2.24.0->-r requirements-test.txt (line 6)) (1.7.0)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from flask>=2.0.0->locust==2.24.0->-r requirements-test.txt (line 6)) (7.0.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from flask>=2.0.0->locust==2.24.0->-r requirements-test.txt (line 6)) (2.1.2)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from flask>=2.0.0->locust==2.24.0->-r requirements-test.txt (line 6)) (3.1.2)
# Collecting zope.interface
#   Downloading zope.interface-7.2-cp39-cp39-macosx_11_0_arm64.whl (208 kB)
#      |████████████████████████████████| 208 kB 4.0 MB/s eta 0:00:01
# Collecting zope.event
#   Downloading zope.event-5.0-py3-none-any.whl (6.8 kB)
# Collecting greenlet>=3.1.1
#   Using cached greenlet-3.1.1-cp39-cp39-macosx_11_0_universal2.whl (270 kB)
# Collecting brotli
#   Downloading Brotli-1.1.0-cp39-cp39-macosx_10_9_universal2.whl (873 kB)
#      |████████████████████████████████| 873 kB 3.2 MB/s eta 0:00:01
# Requirement already satisfied: urllib3 in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from geventhttpclient>=2.0.11->locust==2.24.0->-r requirements-test.txt (line 6)) (2.2.1)
# Requirement already satisfied: zipp>=0.5 in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=3.6.0->flask>=2.0.0->locust==2.24.0->-r requirements-test.txt (line 6)) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from Jinja2>=3.1.2->flask>=2.0.0->locust==2.24.0->-r requirements-test.txt (line 6)) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->locust==2.24.0->-r requirements-test.txt (line 6)) (3.3.2)
# Requirement already satisfied: typing-extensions>=4.1 in /Users/kostiks/Library/Python/3.9/lib/python/site-packages (from anyio->httpx==0.27.0->-r requirements-test.txt (line 5)) (4.12.2)
# Requirement already satisfied: setuptools in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from zope.event->gevent>=22.10.2->locust==2.24.0->-r requirements-test.txt (line 6)) (58.0.4)
# Building wheels for collected packages: gevent, roundrobin
#   Building wheel for gevent (PEP 517) ... done
#   Created wheel for gevent: filename=gevent-24.11.1-cp39-cp39-macosx_10_9_universal2.whl size=2961986 sha256=df8901f884efa2c1f91f41e0e2af37ddc40f9b0144c669c3f17face0285b4b13
#   Stored in directory: /Users/kostiks/Library/Caches/pip/wheels/6e/ed/50/396606ea0de86a3d7ebbc6acf3a7fc9c2ef33baf7b7907cd75
#   Building wheel for roundrobin (setup.py) ... done
#   Created wheel for roundrobin: filename=roundrobin-0.0.4-py3-none-any.whl size=4033 sha256=003b60649bb1314b5ec2e8a3125c0fae212f4588f3175e4dbc12a9109f6e2af6
#   Stored in directory: /Users/kostiks/Library/Caches/pip/wheels/f0/a5/95/f5228e0966ecd65b54419065aefc1892af1fc06652fcb9f4d0
# Successfully built gevent roundrobin
# Installing collected packages: zope.interface, zope.event, greenlet, gevent, coverage, brotli, roundrobin, pytest, geventhttpclient, Flask-Login, Flask-Cors, ConfigArgParse, pytest-mock, pytest-cov, pytest-asyncio, locust
#   Attempting uninstall: pytest
#     Found existing installation: pytest 7.4.2
#     Uninstalling pytest-7.4.2:
#       Successfully uninstalled pytest-7.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qai-hub-models 0.5.1 requires numpy==1.23.1, but you have numpy 1.26.4 which is incompatible.
# qai-hub-models 0.5.1 requires opencv-python==4.8.1.78, but you have opencv-python 4.9.0.80 which is incompatible.
# qai-hub-models 0.5.1 requires pandas==1.5.3, but you have pandas 2.2.3 which is incompatible.
# qai-hub-models 0.5.1 requires pytest==7.4.2, but you have pytest 8.0.2 which is incompatible.
# qai-hub-models 0.5.1 requires scipy==1.8.1, but you have scipy 1.13.1 which is incompatible.
# qai-hub-models 0.5.1 requires typing-extensions==4.5.0, but you have typing-extensions 4.12.2 which is incompatible.
# qai-hub-models 0.5.1 requires urllib3==1.26.18, but you have urllib3 2.2.1 which is incompatible.
# Successfully installed ConfigArgParse-1.7 Flask-Cors-5.0.1 Flask-Login-0.6.3 brotli-1.1.0 coverage-7.4.3 gevent-24.11.1 geventhttpclient-2.3.3 greenlet-3.1.1 locust-2.24.0 pytest-8.0.2 pytest-asyncio-0.23.5 pytest-cov-4.1.0 pytest-mock-3.12.0 roundrobin-0.0.4 zope.event-5.0 zope.interface-7.2
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pytest
# Out:
# ImportError while loading conftest '/Users/kostiks/study/ai_masters/ai_python/fastapi_project/tests/conftest.py'.
# tests/conftest.py:16: in <module>
#     from src.application.main import app
# src/application/main.py:9: in <module>
#     Base.metadata.create_all(bind=engine)
# /Library/Python/3.9/site-packages/sqlalchemy/sql/schema.py:5825: in create_all
#     bind._run_ddl_visitor(
# /Library/Python/3.9/site-packages/sqlalchemy/engine/base.py:3253: in _run_ddl_visitor
#     with self.begin() as conn:
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/contextlib.py:117: in __enter__
#     return next(self.gen)
# /Library/Python/3.9/site-packages/sqlalchemy/engine/base.py:3243: in begin
#     with self.connect() as conn:
# /Library/Python/3.9/site-packages/sqlalchemy/engine/base.py:3279: in connect
#     return self._connection_cls(self)
# /Library/Python/3.9/site-packages/sqlalchemy/engine/base.py:147: in __init__
#     Connection._handle_dbapi_exception_noconnection(
# /Library/Python/3.9/site-packages/sqlalchemy/engine/base.py:2443: in _handle_dbapi_exception_noconnection
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
# /Library/Python/3.9/site-packages/sqlalchemy/engine/base.py:145: in __init__
#     self._dbapi_connection = engine.raw_connection()
# /Library/Python/3.9/site-packages/sqlalchemy/engine/base.py:3303: in raw_connection
#     return self.pool.connect()
# /Library/Python/3.9/site-packages/sqlalchemy/pool/base.py:449: in connect
#     return _ConnectionFairy._checkout(self)
# /Library/Python/3.9/site-packages/sqlalchemy/pool/base.py:1263: in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
# /Library/Python/3.9/site-packages/sqlalchemy/pool/base.py:712: in checkout
#     rec = pool._do_get()
# /Library/Python/3.9/site-packages/sqlalchemy/pool/impl.py:180: in _do_get
#     self._dec_overflow()
# /Library/Python/3.9/site-packages/sqlalchemy/util/langhelpers.py:146: in __exit__
#     raise exc_value.with_traceback(exc_tb)
# /Library/Python/3.9/site-packages/sqlalchemy/pool/impl.py:177: in _do_get
#     return self._create_connection()
# /Library/Python/3.9/site-packages/sqlalchemy/pool/base.py:390: in _create_connection
#     return _ConnectionRecord(self)
# /Library/Python/3.9/site-packages/sqlalchemy/pool/base.py:674: in __init__
#     self.__connect()
# /Library/Python/3.9/site-packages/sqlalchemy/pool/base.py:901: in __connect
#     pool.logger.debug("Error on connect(): %s", e)
# /Library/Python/3.9/site-packages/sqlalchemy/util/langhelpers.py:146: in __exit__
#     raise exc_value.with_traceback(exc_tb)
# /Library/Python/3.9/site-packages/sqlalchemy/pool/base.py:896: in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
# /Library/Python/3.9/site-packages/sqlalchemy/engine/create.py:643: in connect
#     return dialect.connect(*cargs, **cparams)
# /Library/Python/3.9/site-packages/sqlalchemy/engine/default.py:616: in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
# ../../../../Library/Python/3.9/lib/python/site-packages/psycopg2/__init__.py:122: in connect
#     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
# E   sqlalchemy.exc.OperationalError: (psycopg2.OperationalError) could not translate host name "db" to address: nodename nor servname provided, or not known
# E
# E   (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# !pip3 install passlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting passlib
#   Downloading passlib-1.7.4-py2.py3-none-any.whl (525 kB)
#      |████████████████████████████████| 525 kB 4.5 MB/s eta 0:00:01
# Installing collected packages: passlib
# Successfully installed passlib-1.7.4
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# ---
#
# ## **🔴 Функционал сервиса:**
#
# > Ниже представлены функции - 5 обязательных и несколько дополнительных (можно придумать свои).
#
# ### **⭕ Обязательные функции:**
# 1. **Создание / удаление / изменение / получение информации по короткой ссылке:**
#   - `POST /links/shorten` – создает короткую ссылку.
#   - `GET /links/{short_code}` – перенаправляет на оригинальный URL.
#   - `DELETE /links/{short_code}` – удаляет связь.
#   - `PUT /links/{short_code}` – обновляет URL (То есть, короткий адрес. Будем засчитывать и другую реализацию - когда к короткой ссылке привязывается новая длинная).
# 2. **Статистика по ссылке:**
#   - `GET /links/{short_code}/stats`
#   - Отображает оригинальный URL, возвращает дату создания, количество переходов, дату последнего использовани.
# 3. **Создание кастомных ссылок (уникальный alias):**
#   - `POST /links/shorten` (с передачей `custom_alias`).
#   - Важно проверить уникальность `alias`.
# 4. **Поиск ссылки по оригинальному URL:**
#   - `GET /links/search?original_url={url}`
# 5. **Указание времени жизни ссылки:**
#   - `POST /links/shorten` (создается с параметром `expires_at` в формате даты с точностью до минуты).
#   - После указанного времени короткая ссылка автоматически удаляется.
#
#
#
# ### **⭕ Дополнительные функции:**
#
# > Каждый метод должна быть отличим от других по логике и функционалу. Вы можете придумать свой вариант, но ниже будет пару наших идей.
#
# - **Удаление неиспользуемых ссылок:**
#   - К примеру, спустя по умолчанию спустя `N` дней после последнего перехода по ссылке.
#   - `N` задается для всех ссылок разом.
# - Отображение истории всех истекших ссылок с информацией о них.
# - Группировка ссылок по проектам.
# - Создание коротких ссылок для незарегистрированных пользователей.
#
#
# ### **⭕ Регистрация:**
# Так как пользователь должен иметь возможность управлять ссылками, необходимо сделать простую регистрацию.
#
# Изменение и удаление ссылки должно быть доступно только зарегистрированным пользователям, в то время как `GET` / `POST` - всем. Чтобы это поддерживать - храним информацию о том какой пользователь создавал ссылку (залогиненный или нет) и кладем эту информацию в базу данных.
#
# ### **⭕ База данных и кэширование:**
#
# - Используйте БД (к примеру, `PostgreSQL`) как основное хранилище ссылок, так как позволяет легко обновлять, удалять и искать данные.
#
# - **Обязательно используйте `Redis` или аналоги** для кэширования тех данных, где это нужно и полезно (к примеру, кэширование самых популярных ссылок). **Наличие кэширования для endpoint-ов будет оцениваться.**
#
# - Не забудьте настроить очистку кэша при обновлении / удалении ссылки.

# %% [markdown]
# ---
#
# ## **🔴 Формат сдачи работы:**
#
# > Работа сдается в AnyTask.
#
# - Ссылка на код на `GitHub`, включая `docker` или `docker-compose`.
# - Cсылку на развернутый работающий сервис (можете использовать этот [хостинг](https://dashboard.render.com/)).
#
# - `README.md` в репозитории, содержащий:
#   * Описание API.
#   * Примеры запросов.
#   * Инструкцию по запуску.
#   * Описание БД (при наличии).

# %% [markdown]
# ---
#
# ## **🔴 Критерии оценки:**
#
# - 5 Обязательных функций - до `7.5` баллов (`1.5` каждая)
# - Наличие кэширования важных эндпоинтов - `1` балл.
# - 2 Дополнительные функции - до `1.5` баллов (по `0.75` каждая).
# - При реализации большей функциональности, нестандартных корректных подходах и т.п. оценивание **на усмотрение** проверяющего.
#
# Всего за задание не может быть больше 14 баллов.
